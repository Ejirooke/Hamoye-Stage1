# %%
import pandas as pd
import numpy as np

days = pd.Series(['Monday', 'Tuesday', 'Wednesday'])
print(days)
days_list = np.array(['Monday', 'Tuesday', 'Wednesday'])
numpy_days = pd.Series(days_list)
print(numpy_days)
# Out:
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# dtype: object
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# dtype: object

# %%
days = pd.Series(['Monday', 'Tuesday', 'Wednesday'])
index=(['a','b','c'])

days1 = pd.Series({'a':'Monday','b':'Tuesday','c':'Wednesday'})
days
days1
days[0]
days[1:]
# Out:
# 1      Tuesday
# 2    Wednesday
# dtype: object

# %%
print(pd.DataFrame())
df_dict = {'Country':['Ghana','Kenya','Nigeria','Togo'],
           'Capital':['Accra','Nairobi','Abuja','Lome'],
           'Population':['10000','8500','35000','12000'],
           'Age':['60','70','80','75']
}
df = pd.DataFrame(df_dict, index=[2,4,6,8])
df
df1 = pd.DataFrame(df, columns=['Country', 'Capital','Population','Age'],
                   index=[2,4,6,8])
df1
df.iloc[3]
df.loc[6]
df['Capital']
df.at[6, 'Country']
df.at[8, 'Age']
df.iat[3,1]

df.sum()['Population'] = 65500
df.mean()
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5c39b855fcc0> in <module>
# ----> 1 print(pd.DataFrame())
#       2 df_dict = {'Country':['Ghana','Kenya','Nigeria','Togo'],
#       3            'Capital':['Accra','Nairobi','Abuja','Lome'],
#       4            'Population':['10000','8500','35000','12000'],
#       5            'Age':['60','70','80','75']
#
# NameError: name 'pd' is not defined
